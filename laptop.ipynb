# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Rahul Singh\OneDrive\ドキュメント\CRT\pandas\laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# # head function for top rows and by default it print 5 rows

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %% [markdown]
# # Tail function use for last rows and by default it print 5 last rows

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %% [markdown]
# # info function use showing infromation of dataset
# # Object is showing string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %% [markdown]
# # decsribe function showing mean and max value of numerical value of  the dataset

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %% [markdown]
# # columns showing all  the columns of the dataset
# # columns is not a function

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %% [markdown]
# # select

# %%
df.select_dtypes(exclude='O')
# Out:
#       Price  Number of Ratings  Number of Reviews
# 0     34649                  3                  0
# 1     38999                 65                  5
# 2     39999                  8                  1
# 3     69990                  0                  0
# 4     26990                  0                  0
# ..      ...                ...                ...
# 818  135990                  0                  0
# 819  144990                  0                  0
# 820  149990                  0                  0
# 821  142990                  0                  0
# 822   57490                 18                  4
#
# [823 rows x 3 columns]

# %%
df.select_dtypes(include='O')
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.select_dtypes(exclude='O').head()
# Out:
#    Price  Number of Ratings  Number of Reviews
# 0  34649                  3                  0
# 1  38999                 65                  5
# 2  39999                  8                  1
# 3  69990                  0                  0
# 4  26990                  0                  0

# %% [markdown]
# # unique function showing unique brand of the dataset

# %%
df["brand"].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %% [markdown]
# # nunique function showing number of unique brand

# %%
df["brand"].nunique()
# Out:
# 8

# %%
print(df["processor_brand"].nunique())
df["processor_brand"].unique()
# Out:
# 3
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
df["processor_gnrtn"].nunique()
# Out:
# 8

# %%
df["processor_name"].nunique()
# Out:
# 11

# %%
print(df["ram_gb"].unique())
df["ram_gb"].nunique()
# Out:
# ['4 GB' '8 GB' '16 GB' '32 GB']
# 4

# %%
df["os"].nunique()
# Out:
# 3

# %% [markdown]
# # value count function use for counting the value of brand

# %%
df["brand"].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
df["brand"].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
apple=df[df["brand"] == "APPLE"]
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
apple=df[df["brand"] == "ASUS"]
apple
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
apple['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD'], dtype=object)

# %%
apple_m1_chip=apple[apple['processor_brand'] == 'M1'].head()
apple_m1_chip
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
touchscreen=apple_m1_chip[apple_m1_chip['Touchscreen']== 'YES']
touchscreen
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %% [markdown]
# # max function use for finding the maximum price of the apple

# %%
apple["Price"].max()
# Out:
# np.int64(441990)

# %%
apple["processor_brand"].unique()
# Out:
# array(['Intel', 'AMD'], dtype=object)

# %%
apple_intel=apple[apple["processor_brand"] == 'Intel']
apple_intel
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 630  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 632  ASUS           Intel   Pentium Quad   Not Available   4 GB   LPDDR4
# 633  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 634  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
# 635  ASUS           Intel   Pentium Quad   Not Available   4 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
apple_gb=apple_intel[apple_intel['ram_gb'] == "8 GB"]
apple_gb
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 27   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 32   ASUS           Intel        Core i3            11th   8 GB     DDR4
# 33   ASUS           Intel        Core i3            11th   8 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 473  ASUS           Intel        Core i5            11th   8 GB     DDR4
# 486  ASUS           Intel        Core i7            10th   8 GB     DDR4
# 491  ASUS           Intel        Core i7            11th   8 GB     DDR4
# 531  ASUS           Intel        Core i7             8th   8 GB   LPDDR3
# 625  ASUS           Intel   Pentium Quad   Not Available   8 GB  LPDDR4X
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
# apple_price=apple_gb[apple_gb["price"] <=100000]

# %% [markdown]
# #ASUS

# %%
ASUS=df[df["brand"] == "ASUS"]
ASUS_10thgen=ASUS[ASUS['processor_gnrtn'] == '10th']

# %%
ASUS_10thgen_ram=ASUS_10thgen[ASUS_10thgen['ram_type']=="LPDDR3"]

# %%
ASUS_10thgen_Windows=ASUS_10thgen_ram[ASUS_10thgen_ram["os"]=="Windows"]

# %%
ASUS_10thgen_GCG=ASUS_10thgen_Windows[ASUS_10thgen_Windows["graphic_card_gb"] == "2 GB"]

# %%
ASUS_10thgen_price=ASUS_10thgen_GCG[ASUS_10thgen_GCG["Price"] <=120000]

# %%
ASUS_10thgen_price
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 381  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
#
#         ssd   hdd       os  os_bit graphic_card_gb  weight warranty  \
# 381  512 GB  0 GB  Windows  64-bit            2 GB  Casual   1 year
#
#     Touchscreen msoffice   Price   rating  Number of Ratings  \
# 381          No      Yes  105990  5 stars                  4
#
#      Number of Reviews
# 381                  0

# %% [markdown]
#  <!-- brand= acar , processerr = intal ,ram = 8gb, ssd = 512,os = window,4gb graphic card,laptop = touchscreen ,price less then 70000 -->

# %%
ACER=df[df["brand"] == "acer"]
ACER=ACER[ACER["ram_gb"] == "8 GB"]
ACER=ACER[ACER["processor_brand"]== "Intel"]
ACER=ACER[ACER["ssd"]<= "512 GB"]
ACER=ACER[ACER["os"]== "Windows"]
ACER=ACER[ACER["graphic_card_gb"]== "4 GB"]
# ACER=ACER[ACER["Touchscreen"]=="NO"]
ACER=ACER[ACER['Price'] <=70000]
ACER
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
#
#       ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 196  0 GB  512 GB  Windows  32-bit            4 GB  Casual  No warranty
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 196          No       No  50990  4 stars              10966               1185

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
acer=df[df['brand'] == 'acer']

# %%
acer=acer[acer['ram_gb'] == '8 GB']

# %%
acer=acer[acer["processor_brand"] == "Intel"]

# %%
acer=acer[acer["ssd"] <="512 GB"]

# %%
acer=acer[acer["os"] == "Windows"]

# %%
acer=acer[acer["graphic_card_gb"] =="4 GB"]

# %%
acer[acer["Price"] <= 100000]
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 325  acer           Intel        Core i5             8th   8 GB     DDR4
#
#         ssd     hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 196    0 GB  512 GB  Windows  32-bit            4 GB  Casual  No warranty
# 325  512 GB    0 GB  Windows  64-bit            4 GB  Casual       1 year
#
#     Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# 196          No       No  50990  4 stars              10966               1185
# 325          No       No  99500  3 stars                  0                  0
